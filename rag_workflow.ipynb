# %% [markdown]
# # Local RAG Workflow (Overview)
#
# This notebook demonstrates a minimal local RAG pipeline using:
# - Ollama for embeddings & chat LLMs
# - Chroma as a local vector store
# - PyMuPDF for PDF ingestion
#
# Sections:
# 1) Setup: install dependencies and verify connectivity
# 2) Ingestion: load PDFs, split into chunks, and index into Chroma
# 3) Retrieval & QA: generate multi-query retriever and ask the model
#
# Run cells sequentially. If you run into errors, check that `ollama serve` is running locally.

# %%
pip install ollama
# Out:
# Requirement already satisfied: ollama in ./venv/lib/python3.9/site-packages (0.6.1)
# Requirement already satisfied: httpx>=0.27 in ./venv/lib/python3.9/site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in ./venv/lib/python3.9/site-packages (from ollama) (2.12.5)
# Requirement already satisfied: anyio in ./venv/lib/python3.9/site-packages (from httpx>=0.27->ollama) (4.12.0)
# Requirement already satisfied: idna in ./venv/lib/python3.9/site-packages (from httpx>=0.27->ollama) (3.11)
# Requirement already satisfied: certifi in ./venv/lib/python3.9/site-packages (from httpx>=0.27->ollama) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.9/site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./venv/lib/python3.9/site-packages (from pydantic>=2.9->ollama) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.9/site-packages (from pydantic>=2.9->ollama) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.9/site-packages (from pydantic>=2.9->ollama) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.14.1 in ./venv/lib/python3.9/site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./venv/lib/python3.9/site-packages (from anyio->httpx>=0.27->ollama) (1.3.1)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/mohitxsh/Dev/rag/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install chromadb
# Out:
# Requirement already satisfied: chromadb in ./venv/lib/python3.9/site-packages (1.3.7)
# Requirement already satisfied: grpcio>=1.58.0 in ./venv/lib/python3.9/site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in ./venv/lib/python3.9/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in ./venv/lib/python3.9/site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in ./venv/lib/python3.9/site-packages (from chromadb) (0.39.0)
# Requirement already satisfied: pydantic>=1.9 in ./venv/lib/python3.9/site-packages (from chromadb) (2.12.5)
# Requirement already satisfied: overrides>=7.3.1 in ./venv/lib/python3.9/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: orjson>=3.9.12 in ./venv/lib/python3.9/site-packages (from chromadb) (3.11.5)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in ./venv/lib/python3.9/site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in ./venv/lib/python3.9/site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in ./venv/lib/python3.9/site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: typer>=0.9.0 in ./venv/lib/python3.9/site-packages (from chromadb) (0.20.1)
# Requirement already satisfied: mmh3>=4.0.1 in ./venv/lib/python3.9/site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in ./venv/lib/python3.9/site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: rich>=10.11.0 in ./venv/lib/python3.9/site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: importlib-resources in ./venv/lib/python3.9/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: pypika>=0.48.9 in ./venv/lib/python3.9/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: pyyaml>=6.0.0 in ./venv/lib/python3.9/site-packages (from chromadb) (6.0.3)
# Requirement already satisfied: tenacity>=8.2.3 in ./venv/lib/python3.9/site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: bcrypt>=4.0.1 in ./venv/lib/python3.9/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: pybase64>=1.4.1 in ./venv/lib/python3.9/site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: onnxruntime>=1.14.1 in ./venv/lib/python3.9/site-packages (from chromadb) (1.19.2)
# Requirement already satisfied: tqdm>=4.65.0 in ./venv/lib/python3.9/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: build>=1.0.3 in ./venv/lib/python3.9/site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: httpx>=0.27.0 in ./venv/lib/python3.9/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: kubernetes>=28.1.0 in ./venv/lib/python3.9/site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./venv/lib/python3.9/site-packages (from chromadb) (4.15.0)
# Requirement already satisfied: numpy>=1.22.5 in ./venv/lib/python3.9/site-packages (from chromadb) (2.0.2)
# Requirement already satisfied: importlib-metadata>=4.6 in ./venv/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (8.7.1)
# Requirement already satisfied: pyproject_hooks in ./venv/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in ./venv/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (2.3.0)
# Requirement already satisfied: packaging>=19.1 in ./venv/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: anyio in ./venv/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (4.12.0)
# Requirement already satisfied: certifi in ./venv/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (2025.11.12)
# Requirement already satisfied: idna in ./venv/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (3.11)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in ./venv/lib/python3.9/site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb) (3.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./venv/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./venv/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: attrs>=22.2.0 in ./venv/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./venv/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (0.27.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in ./venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: google-auth>=1.0.1 in ./venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.45.0)
# Requirement already satisfied: requests-oauthlib in ./venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3<2.4.0,>=1.24.2 in ./venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in ./venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: six>=1.9.0 in ./venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: durationpy>=0.7 in ./venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: requests in ./venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.32.5)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./venv/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./venv/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in ./venv/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.4)
# Requirement already satisfied: flatbuffers in ./venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in ./venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.2)
# Requirement already satisfied: sympy in ./venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: coloredlogs in ./venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in ./venv/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in ./venv/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in ./venv/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in ./venv/lib/python3.9/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: distro>=1.5.0 in ./venv/lib/python3.9/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: backoff>=1.10.0 in ./venv/lib/python3.9/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (0.4.2)
# Requirement already satisfied: pydantic-core==2.41.5 in ./venv/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (2.41.5)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.9/site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./venv/lib/python3.9/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./venv/lib/python3.9/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in ./venv/lib/python3.9/site-packages (from tokenizers>=0.13.2->chromadb) (1.2.3)
# Requirement already satisfied: typer-slim in ./venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (0.20.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in ./venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Requirement already satisfied: shellingham in ./venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.4)
# Requirement already satisfied: fsspec>=2023.5.0 in ./venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.10.0)
# Requirement already satisfied: filelock in ./venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.19.1)
# Requirement already satisfied: click>=8.0.0 in ./venv/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: python-dotenv>=0.13 in ./venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.1)
# Requirement already satisfied: websockets>=10.4 in ./venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: httptools>=0.6.3 in ./venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in ./venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in ./venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./venv/lib/python3.9/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in ./venv/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in ./venv/lib/python3.9/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/mohitxsh/Dev/rag/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Connectivity & Imports
# This section imports the libraries used in the notebook and performs a quick connectivity test to ensure `ollama` is reachable.

# %%
# Imports for connectivity check
import ollama
import chromadb

# Test if Ollama is reachable. Ensure you have run `ollama serve` locally before executing.
try:
    response = ollama.chat(model='llama3', messages=[
        {'role': 'user', 'content': 'Hello, are you there?'}
    ])
    print("Ollama Connection Success:", response['message']['content'])
except Exception as e:
    print("Error connecting to Ollama. Make sure 'ollama serve' is running in your terminal.")
    print(e)
# Out:
# Ollama Connection Success: Hello! Yes, I'm here. I'm an AI assistant trained to help answer your questions and provide information on a wide range of topics. What's on your mind today? Do you have something specific you'd like to chat about or ask me? I'm all ears (or rather, all text)!

# %%
pip install pymupdf
# Out:
# Requirement already satisfied: pymupdf in ./venv/lib/python3.9/site-packages (1.26.5)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/mohitxsh/Dev/rag/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in ./venv/lib/python3.9/site-packages (0.3.11)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.75 in ./venv/lib/python3.9/site-packages (from langchain-text-splitters) (0.3.81)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in ./venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (0.4.37)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in ./venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (9.1.2)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in ./venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (2.12.5)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in ./venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.9/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: requests>=2.0.0 in ./venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: orjson>=3.9.14 in ./venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (3.11.5)
# Requirement already satisfied: certifi in ./venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (2025.11.12)
# Requirement already satisfied: idna in ./venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (3.11)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: anyio in ./venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (4.12.0)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (2.41.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.9/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (2.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.9/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (3.4.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=0.3.75->langchain-text-splitters) (1.3.1)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/mohitxsh/Dev/rag/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U langchain-ollama langchain-chroma langchain_community
# Out:
# Requirement already satisfied: langchain-ollama in ./venv/lib/python3.9/site-packages (0.3.10)
# Requirement already satisfied: langchain-chroma in ./venv/lib/python3.9/site-packages (0.2.6)
# Requirement already satisfied: langchain_community in ./venv/lib/python3.9/site-packages (0.3.31)
# Requirement already satisfied: langchain-core<2.0.0,>=0.3.76 in ./venv/lib/python3.9/site-packages (from langchain-ollama) (0.3.81)
# Requirement already satisfied: ollama<1.0.0,>=0.5.3 in ./venv/lib/python3.9/site-packages (from langchain-ollama) (0.6.1)
# Requirement already satisfied: numpy>=1.26.0 in ./venv/lib/python3.9/site-packages (from langchain-chroma) (2.0.2)
# Requirement already satisfied: chromadb>=1.0.20 in ./venv/lib/python3.9/site-packages (from langchain-chroma) (1.3.7)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in ./venv/lib/python3.9/site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./venv/lib/python3.9/site-packages (from langchain_community) (3.13.2)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in ./venv/lib/python3.9/site-packages (from langchain_community) (6.0.3)
# Requirement already satisfied: langchain<2.0.0,>=0.3.27 in ./venv/lib/python3.9/site-packages (from langchain_community) (0.3.27)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in ./venv/lib/python3.9/site-packages (from langchain_community) (0.4.37)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in ./venv/lib/python3.9/site-packages (from langchain_community) (2.0.45)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in ./venv/lib/python3.9/site-packages (from langchain_community) (0.4.3)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in ./venv/lib/python3.9/site-packages (from langchain_community) (2.11.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./venv/lib/python3.9/site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in ./venv/lib/python3.9/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: aiosignal>=1.4.0 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.7.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.22.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: propcache>=0.2.0 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.4.1)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.8.0)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Requirement already satisfied: typing-extensions>=4.2 in ./venv/lib/python3.9/site-packages (from aiosignal>=1.4.0->aiohttp<4.0.0,>=3.8.3->langchain_community) (4.15.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (5.4.0)
# Requirement already satisfied: mmh3>=4.0.1 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (5.2.0)
# Requirement already satisfied: pypika>=0.48.9 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (0.48.9)
# Requirement already satisfied: build>=1.0.3 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (1.3.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (0.39.0)
# Requirement already satisfied: grpcio>=1.58.0 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (1.76.0)
# Requirement already satisfied: tokenizers>=0.13.2 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (0.22.1)
# Requirement already satisfied: overrides>=7.3.1 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (7.7.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (1.39.1)
# Requirement already satisfied: orjson>=3.9.12 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (3.11.5)
# Requirement already satisfied: kubernetes>=28.1.0 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (34.1.0)
# Requirement already satisfied: jsonschema>=4.19.0 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (4.25.1)
# Requirement already satisfied: tqdm>=4.65.0 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (4.67.1)
# Requirement already satisfied: onnxruntime>=1.14.1 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (1.19.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (1.39.1)
# Requirement already satisfied: pybase64>=1.4.1 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (1.4.3)
# Requirement already satisfied: bcrypt>=4.0.1 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (5.0.0)
# Requirement already satisfied: httpx>=0.27.0 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (0.28.1)
# Requirement already satisfied: pydantic>=1.9 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (2.12.5)
# Requirement already satisfied: rich>=10.11.0 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (14.2.0)
# Requirement already satisfied: typer>=0.9.0 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (0.20.1)
# Requirement already satisfied: importlib-resources in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (6.5.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in ./venv/lib/python3.9/site-packages (from chromadb>=1.0.20->langchain-chroma) (1.39.1)
# Requirement already satisfied: packaging>=19.1 in ./venv/lib/python3.9/site-packages (from build>=1.0.3->chromadb>=1.0.20->langchain-chroma) (25.0)
# Requirement already satisfied: pyproject_hooks in ./venv/lib/python3.9/site-packages (from build>=1.0.3->chromadb>=1.0.20->langchain-chroma) (1.2.0)
# Requirement already satisfied: importlib-metadata>=4.6 in ./venv/lib/python3.9/site-packages (from build>=1.0.3->chromadb>=1.0.20->langchain-chroma) (8.7.1)
# Requirement already satisfied: tomli>=1.1.0 in ./venv/lib/python3.9/site-packages (from build>=1.0.3->chromadb>=1.0.20->langchain-chroma) (2.3.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./venv/lib/python3.9/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./venv/lib/python3.9/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain_community) (3.26.2)
# Requirement already satisfied: certifi in ./venv/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (2025.11.12)
# Requirement already satisfied: anyio in ./venv/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (4.12.0)
# Requirement already satisfied: httpcore==1.* in ./venv/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (1.0.9)
# Requirement already satisfied: idna in ./venv/lib/python3.9/site-packages (from httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (3.11)
# Requirement already satisfied: h11>=0.16 in ./venv/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in ./venv/lib/python3.9/site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb>=1.0.20->langchain-chroma) (3.23.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./venv/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb>=1.0.20->langchain-chroma) (0.27.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./venv/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb>=1.0.20->langchain-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./venv/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb>=1.0.20->langchain-chroma) (0.36.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in ./venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (1.9.0)
# Requirement already satisfied: six>=1.9.0 in ./venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (1.17.0)
# Requirement already satisfied: requests-oauthlib in ./venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (2.0.0)
# Requirement already satisfied: urllib3<2.4.0,>=1.24.2 in ./venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in ./venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (0.10)
# Requirement already satisfied: google-auth>=1.0.1 in ./venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (2.45.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in ./venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./venv/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (0.4.2)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in ./venv/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (6.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./venv/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (4.9.1)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in ./venv/lib/python3.9/site-packages (from langchain<2.0.0,>=0.3.27->langchain_community) (0.3.11)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in ./venv/lib/python3.9/site-packages (from langchain-core<2.0.0,>=0.3.76->langchain-ollama) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.9/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=0.3.76->langchain-ollama) (3.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in ./venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in ./venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: sympy in ./venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (1.14.0)
# Requirement already satisfied: protobuf in ./venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (6.33.2)
# Requirement already satisfied: coloredlogs in ./venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in ./venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (25.12.19)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in ./venv/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.20->langchain-chroma) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in ./venv/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.20->langchain-chroma) (1.39.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in ./venv/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.20->langchain-chroma) (1.72.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in ./venv/lib/python3.9/site-packages (from opentelemetry-sdk>=1.2.0->chromadb>=1.0.20->langchain-chroma) (0.60b1)
# Requirement already satisfied: distro>=1.5.0 in ./venv/lib/python3.9/site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (1.9.0)
# Requirement already satisfied: backoff>=1.10.0 in ./venv/lib/python3.9/site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (2.2.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (0.6.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./venv/lib/python3.9/site-packages (from pydantic>=1.9->chromadb>=1.0.20->langchain-chroma) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv/lib/python3.9/site-packages (from pydantic>=1.9->chromadb>=1.0.20->langchain-chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./venv/lib/python3.9/site-packages (from pydantic>=1.9->chromadb>=1.0.20->langchain-chroma) (2.41.5)
# Requirement already satisfied: python-dotenv>=0.21.0 in ./venv/lib/python3.9/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./venv/lib/python3.9/site-packages (from rich>=10.11.0->chromadb>=1.0.20->langchain-chroma) (2.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./venv/lib/python3.9/site-packages (from rich>=10.11.0->chromadb>=1.0.20->langchain-chroma) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in ./venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=1.0.20->langchain-chroma) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in ./venv/lib/python3.9/site-packages (from tokenizers>=0.13.2->chromadb>=1.0.20->langchain-chroma) (1.2.3)
# Requirement already satisfied: shellingham in ./venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.20->langchain-chroma) (1.5.4)
# Requirement already satisfied: typer-slim in ./venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.20->langchain-chroma) (0.20.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in ./venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.20->langchain-chroma) (1.2.0)
# Requirement already satisfied: filelock in ./venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.20->langchain-chroma) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in ./venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.20->langchain-chroma) (2025.10.0)
# Requirement already satisfied: click>=8.0.0 in ./venv/lib/python3.9/site-packages (from typer>=0.9.0->chromadb>=1.0.20->langchain-chroma) (8.1.8)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./venv/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community) (1.1.0)
# Requirement already satisfied: uvloop>=0.15.1 in ./venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (0.22.1)
# Requirement already satisfied: websockets>=10.4 in ./venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (15.0.1)
# Requirement already satisfied: watchfiles>=0.13 in ./venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (1.1.1)
# Requirement already satisfied: httptools>=0.6.3 in ./venv/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (0.7.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./venv/lib/python3.9/site-packages (from anyio->httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in ./venv/lib/python3.9/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in ./venv/lib/python3.9/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./venv/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (1.3.0)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/mohitxsh/Dev/rag/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Part 1: Ingestion — Load & Index Data
#
# This section defines `load_and_index_data(folder_path)`, which:
# - Loads PDF files from a folder using `PyMuPDFLoader`.
# - Splits documents into chunks for embeddings.
# - Creates/persists a Chroma vector DB using `OllamaEmbeddings`.
#
# Run this cell to (re)build the vector store before querying.

# %%
import os
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

from langchain_ollama import ChatOllama, OllamaEmbeddings
from langchain_chroma import Chroma

from langchain.prompts import ChatPromptTemplate, PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain.retrievers.multi_query import MultiQueryRetriever

# Constants
CHROMA_PATH = "./chroma_db"
COLLECTION_NAME = "local-rag"
EMBEDDING_MODEL = "llama3" 
LLM_MODEL = "llama3"

# --- PART 1: INGESTION (Loading & Embedding) ---

def load_and_index_data(folder_path):
    # 1. Check if DB exists to save time
    if os.path.exists(CHROMA_PATH) and os.listdir(CHROMA_PATH):
        print("Vector DB already exists. Loading...")
        return Chroma(
            persist_directory=CHROMA_PATH, 
            embedding_function=OllamaEmbeddings(model=EMBEDDING_MODEL), 
            collection_name=COLLECTION_NAME
        )

    print("Creating new Vector DB...")
    
    # 2. Load PDFs
    if not os.path.exists(folder_path):
        print(f"Folder {folder_path} not found.")
        return None
        
    documents = []
    for filename in os.listdir(folder_path):
        if filename.endswith('.pdf'):
            file_path = os.path.join(folder_path, filename)
            loader = PyMuPDFLoader(file_path)
            documents.extend(loader.load())

    # 3. Split Text
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
    chunks = text_splitter.split_documents(documents)
    
    # 4. Create DB
    # Using the new OllamaEmbeddings from langchain_ollama
    embedding = OllamaEmbeddings(model=EMBEDDING_MODEL)
    
    # Using the new Chroma from langchain_chroma
    vector_db = Chroma.from_documents(
        documents=chunks,
        embedding=embedding,
        collection_name=COLLECTION_NAME,
        persist_directory=CHROMA_PATH
    )
    
    return vector_db

# Initialize the DB
vector_db = load_and_index_data("./data")
print("Database ready.")
# Out:
# /Users/mohitxsh/Dev/rag/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Vector DB already exists. Loading...
# Database ready.

# %% [markdown]
# ## Part 2: Retrieval & QA
# The following cells build the retriever and the QA chain. The `ask_rag` function generates multiple query variants, retrieves relevant chunks, and asks the LLM to answer using only the provided context.

# %%
def ask_rag(question, vector_db):
    if not question or not vector_db:
        return None
        
    llm = ChatOllama(model=LLM_MODEL)

    # Multi-Query Prompt
    QUERY_PROMPT = PromptTemplate(
        input_variables=["question"],
        template="""You are an AI language model assistant. Your task is to generate five
        different versions of the given user question to retrieve relevant documents from
        a vector database. By generating multiple perspectives on the user question, your
        goal is to help the user overcome some of the limitations of the distance-based
        similarity search. Provide these alternative questions separated by newlines.
        Original question: {question}""",
    )

    # Retriever
    retriever = MultiQueryRetriever.from_llm(
        vector_db.as_retriever(), 
        llm,
        prompt=QUERY_PROMPT
    )

    # Answer Prompt
    template = """Answer the question based ONLY on the following context:
    {context}
    Question: {question}
    """
    answer_prompt = ChatPromptTemplate.from_template(template)

    # Chain
    chain = (
        {"context": retriever, "question": RunnablePassthrough()}
        | answer_prompt
        | llm
        | StrOutputParser()
    )

    print(f"Thinking... (Generating variations and searching)")
    response = chain.invoke(question)
    
    return response

# %%
vector_db = load_and_index_data("./data")
if vector_db:
    # Use the defined `ask_rag` function to query the DB
    answer = ask_rag("What should I do to avoid hearing damage while using my mac?", vector_db)
    print("\n--- Answer ---\n")
    print(answer)
# Out:
# Vector DB already exists. Loading...
# Thinking... (Generating variations and searching)
#
# --- Answer ---
#
# Based on the provided context, the key points are:
#
# 1. Software License Agreement:
# 	* Using MacBook Air constitutes acceptance of Apple and third-party software license terms.
# 2. Apple One-Year Limited Warranty Summary:
# 	* Apple warrants the included hardware product against defects in materials and workmanship for one year from the date of original retail purchase.
# 3. Safety and Handling:
# 	* Avoid hearing damage by not listening at high volume levels for long periods.
# 	* MacBook Air contains magnets that may interfere with medical devices.
# 4. Prolonged Heat Exposure:
# 	* Keep the device on a hard, stable, and well-ventilated work surface when in use or charging to avoid discomfort or injury.
# 5. Regulatory Information:
# 	* The device complies with part 15 of the FCC Rules and ISED Canada licence-exempt RSS standard(s).
# 6. ENERGY STAR Compliance:
# 	* Standard configurations of this product meet the ENERGY STAR guidelines for energy efficiency.
# 7. Disposal and Recycling Information:
# 	* Separate collection and recycling of the product and/or its battery is required at the end of life to conserve natural resources and protect human health and the environment.
# 8. Built-in Battery and Charging:
# 	* The built-in battery should only be replaced or repaired by a trained technician to avoid battery damage, which could cause overheating, fire, or injury.
#
# These are the main points mentioned in the provided context.
